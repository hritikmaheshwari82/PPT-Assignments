# %% [markdown]
# 1)
#
# Region A:
# Sales data: [10, 15, 12, 8, 14]
#
# To calculate the mean sales for Region A, you sum up the sales figures and divide by the number of data points:
#
# Mean sales for Region A = (10 + 15 + 12 + 8 + 14) / 5
#
# Mean sales for Region A = 59 / 5
#
# Mean sales for Region A = 11.8
#
# Region B:
# Sales data: [18, 20, 16, 22, 25]
#
# To calculate the mean sales for Region B, you sum up the sales figures and divide by the number of data points:
#
# Mean sales for Region B = (18 + 20 + 16 + 22 + 25) / 5
#
# Mean sales for Region B = 101 / 5
#
# Mean sales for Region B = 20.2
#
# Therefore, the mean sales for Region A is 11.8, and the mean sales for Region B is 20.2.

# %% [markdown]
# 2)
#
# Survey responses: [4, 5, 2, 3, 5, 4, 3, 2, 4, 5]
#
# To find the mode, you can count the frequency of each unique value and determine which one occurs the most:
#
# Frequency of 2: 2
#
# Frequency of 3: 2
#
# Frequency of 4: 3
#
# Frequency of 5: 3
#
# In this case, both 4 and 5 have the highest frequency, occurring 3 times each. Therefore, the mode of the survey responses is 4 and 5.

# %% [markdown]
# 3)
# Department A:
#
# Salary data:[5000, 6000, 5500, 7000]
#
# Let's arrange the numbers in ascending order:
#
# [5000, 5500, 6000, 7000]
#
# Since there are four numbers, the median will be the average of the two middle values, which are 5500 and 6000.
#
# Median = (5500 + 6000) / 2 = 5750
#
# Department B:
#
# Salary data: [4500, 5500, 5800, 6000, 5200]
#
# Arrange the salary data in ascending order: [4500, 5200, 5500, 5800, 6000]
#
# Since the number of data points is odd, the median is the middle value:
#
# Median salary for Department B = 5500
#
# Therefore, the median salary for Department A is 5750, and the median salary for Department B is 5500.

# %% [markdown]
# 4)
#
# Stock prices: [25.5, 24.8, 26.1, 25.3, 24.9]
#
# Arrange the stock prices in ascending order: [24.8, 24.9, 25.3, 25.5, 26.1]
#
# The lowest value is 24.8, and the highest value is 26.1.
#
# Range = Highest value - Lowest value
#
# Range = 26.1 - 24.8
#
# Range = 1.3
#
# Therefore, the range of the stock prices is 1.3.

# %% [markdown]
# 5)
#
# Here's how you can conduct a t-test to compare the mean scores between Group A and Group B:
#
# Step 1: Calculate the sample means for each group.
#
# Group A: [85, 90, 92, 88, 91]
#
# Mean of Group A = (85 + 90 + 92 + 88 + 91) / 5 = 88.4
#
# Group B: [82, 88, 90, 86, 87]
#
# Mean of Group B = (82 + 88 + 90 + 86 + 87) / 5 = 86.6
#
# Step 2: Calculate the sample variances for each group.
#
# Sample variance of Group A = [(85 - 88.4)^2 + (90 - 88.4)^2 + (92 - 88.4)^2 + (88 - 88.4)^2 + (91 - 88.4)^2] / (5 - 1) = 3.76
#
# Sample variance of Group B = [(82 - 86.6)^2 + (88 - 86.6)^2 + (90 - 86.6)^2 + (86 - 86.6)^2 + (87 - 86.6)^2] / (5 - 1) = 4.64
#
# Step 3: Calculate the pooled standard deviation.
#
# Pooled standard deviation = sqrt[(sample variance of Group A + sample variance of Group B) / (n1 + n2 - 2)]
#
# Pooled standard deviation = sqrt[(3.76 + 4.64) / (5 + 5 - 2)] = sqrt(0.84) = 0.916
#
# Step 4: Calculate the t-statistic.
#
# t = (mean of Group A - mean of Group B) / (pooled standard deviation * sqrt(1/n1 + 1/n2))
#
# t = (88.4 - 86.6) / (0.916 * sqrt(1/5 + 1/5))
#
# t = 1.8 / (0.916 * 0.632) ≈ 3.10
#
# Step 5: Determine the degrees of freedom.
#
# Degrees of freedom = n1 + n2 - 2 = 5 + 5 - 2 = 8
#
# Step 6: Determine the significance level and critical value.
#
# Assuming a significance level of 0.05 (5%), the critical value for a two-tailed t-test with 8 degrees of freedom is approximately ±2.306.
#
# Step 7: Compare the calculated t-value with the critical value.
#
# Since |3.10| > 2.306, the calculated t-value falls outside the range of the critical value. Therefore, we can reject the null hypothesis and conclude that there is a significant difference in the mean scores between Group A and Group B.
#
# In summary, based on the t-test results, there is sufficient evidence to suggest a significant difference in the mean scores between the two teaching methods.

# %% [markdown]
# 6)
#
# Advertising Expenditure (in thousands): [10, 15, 12, 8, 14]
# Sales (in thousands): [25, 30, 28, 20, 26]
#
# Step 1: Calculate the means of both variables.
#
# Mean of Advertising Expenditure = (10 + 15 + 12 + 8 + 14) / 5 = 11.8
#
# Mean of Sales = (25 + 30 + 28 + 20 + 26) / 5 = 25.8
#
# Step 2: Calculate the deviations from the mean for both variables.
#
# Deviation from the mean of Advertising Expenditure = [10 - 11.8, 15 - 11.8, 12 - 11.8, 8 - 11.8, 14 - 11.8] = [-1.8, 3.2, 0.2, -3.8, 2.2]
#
# Deviation from the mean of Sales = [25 - 25.8, 30 - 25.8, 28 - 25.8, 20 - 25.8, 26 - 25.8] = [-0.8, 4.2, 2.2, -5.8, 0.2]
#
# Step 3: Calculate the product of the deviations for each pair of data points.
#
# Product of deviations = [-1.8 * -0.8, 3.2 * 4.2, 0.2 * 2.2, -3.8 * -5.8, 2.2 * 0.2] = [1.44, 13.44, 0.44, 22.04, 0.44]
#
# Step 4: Calculate the sum of the products of deviations.
#
# Sum of products of deviations = 1.44 + 13.44 + 0.44 + 22.04 + 0.44 = 37.8
#
# Step 5: Calculate the standard deviation for both variables.
#
# Standard deviation of Advertising Expenditure = sqrt([(-1.8)^2 + 3.2^2 + 0.2^2 + (-3.8)^2 + 2.2^2] / 4) ≈ 2.4
#
# Standard deviation of Sales = sqrt([(-0.8)^2 + 4.2^2 + 2.2^2 + (-5.8)^2 + 0.2^2] / 4) ≈ 3.6
#
# Step 6: Calculate the correlation coefficient.
#
# Correlation coefficient = Sum of products of deviations / (Standard deviation of Advertising Expenditure * Standard deviation of Sales)
#
# Correlation coefficient = 37.8 / (2.4 * 3.6) ≈ 3.3
#
# Therefore, the correlation coefficient between advertising expenditure and sales is approximately 3.3.

# %% [markdown]
# 7)
#
# Data: [160, 170, 165, 155, 175, 180, 170]
#
# Step 1: Calculate the mean of the heights.
#
# Mean of the heights = (160 + 170 + 165 + 155 + 175 + 180 + 170) / 7 = 167.86 (rounded to two decimal places)
#
# Step 2: Calculate the deviations from the mean for each height.
#
# Deviation from the mean = [160 - 167.86, 170 - 167.86, 165 - 167.86, 155 - 167.86, 175 - 167.86, 180 - 167.86, 170 - 167.86]
#
# Deviation from the mean = [-7.86, 2.14, -2.86, -12.86, 7.14, 12.14, 2.14]
#
# Step 3: Square each deviation.
#
# Squared deviations = [(-7.86)^2, 2.14^2, (-2.86)^2, (-12.86)^2, 7.14^2, 12.14^2, 2.14^2]
#
# Squared deviations = [61.77, 4.58, 8.20, 165.18, 51.07, 147.70, 4.58]
#
# Step 4: Calculate the sum of the squared deviations.
#
# Sum of squared deviations = 61.77 + 4.58 + 8.20 + 165.18 + 51.07 + 147.70 + 4.58 = 443.08
#
# Step 5: Calculate the variance.
#
# Variance = Sum of squared deviations / (number of data points - 1)
# Variance = 443.08 / (7 - 1) = 73.85
#
# Step 6: Calculate the standard deviation.
#
# Standard deviation = sqrt(variance) = sqrt(73.85) ≈ 8.60 (rounded to two decimal places)
#
# Therefore, the standard deviation of the heights is approximately 8.60.

# %% [markdown]
# 8)
#
# Employee Tenure (in years): [2, 3, 5, 4, 6, 2, 4]
#
# Job Satisfaction (on a scale of 1 to 10): [7, 8, 6, 9, 5, 7, 6]
#
# Step 1: Calculate the means of both variables.
#
# Mean of Employee Tenure = (2 + 3 + 5 + 4 + 6 + 2 + 4) / 7 = 3.57 (rounded to two decimal places)
#
# Mean of Job Satisfaction = (7 + 8 + 6 + 9 + 5 + 7 + 6) / 7 = 6.86 (rounded to two decimal places)
#
#
# Step 2: Calculate the deviations from the mean for both variables.
#
# Deviation from the mean of Employee Tenure = [2 - 3.57, 3 - 3.57, 5 - 3.57, 4 - 3.57, 6 - 3.57, 2 - 3.57, 4 - 3.57]
#
# Deviation from the mean of Employee Tenure = [-1.57, -0.57, 1.43, 0.43, 2.43, -1.57, 0.43]
#
# Deviation from the mean of Job Satisfaction = [7 - 6.86, 8 - 6.86, 6 - 6.86, 9 - 6.86, 5 - 6.86, 7 - 6.86, 6 - 6.86]
#
# Deviation from the mean of Job Satisfaction = [0.14, 1.14, -0.86, 2.14, -1.86, 0.14, -0.86]
#
#
# Step 3: Calculate the product of the deviations for each pair of data points.
#
# Product of deviations = [-1.57 * 0.14, -0.57 * 1.14, 1.43 * -0.86, 0.43 * 2.14, 2.43 * -1.86, -1.57 * 0.14, 0.43 * -0.86]
#
# Product of deviations = [-0.220, -0.651, -1.230, 0.922, -4.516, -0.220, -0.371]
#
#
# Step 4: Calculate the sum of the products of deviations.
#
# Sum of products of deviations = -0.220 + -0.651 + -1.230 + 0.922 + -4.516 + -0.220 + -0.371 = -6.186
#
#
# Step 5: Calculate the squared deviations for Employee Tenure.
#
# Squared deviations for Employee Tenure = [(-1.57)^2, (-0.57)^2, (1.43)^2, (0.43)^2, (2.43)^2, (-1.57)^2, (0.43)^2]
#
# Squared deviations for Employee Tenure = [2.4649, 0.3249, 2.0449, 0.1849, 5.9049, 2.4649, 0.1849]
#
#
# Step 6: Calculate the sum of the squared deviations for Employee Tenure.
#
# Sum of squared deviations for Employee Tenure = 2.4649 + 0.3249 + 2.0449 + 0.1849 + 5.9049 + 2.4649 + 0.1849 = 13.5744
#
#
# Step 7: Calculate the slope (b) of the regression line.
#
# b = Sum of products of deviations / Sum of squared deviations for Employee Tenure
#
# b = -6.186 / 13.5744 ≈ -0.455 (rounded to three decimal places)
#
#
# Step 8: Calculate the intercept (a) of the regression line.
#
# a = Mean of Job Satisfaction - (b * Mean of Employee Tenure)
#
# a = 6.86 - (-0.455 * 3.57) ≈ 8.209 (rounded to three decimal places)
#
#
#
#
#
#
#
# Step 9: Formulate the regression equation.
#
# The regression equation is given by:
#
# Job Satisfaction = Intercept + (Slope * Employee Tenure)
#
# Job Satisfaction = 8.209 - 0.455 * Employee Tenure
#
# Therefore, the regression equation to predict job satisfaction based on employee tenure is:
#
# Job Satisfaction = 8.209 - 0.455 * Employee Tenure
#
# The slope (b) of -0.455 indicates that for every one-unit increase in employee tenure, we expect job satisfaction to decrease by approximately 0.455 units. The intercept (a) of 8.209 indicates that when employee tenure is zero, the predicted job satisfaction is approximately 8.209.

# %% [markdown]
# 9)
#
# Medication A: [10, 12, 14, 11, 13]
#
# Medication B: [15, 17, 16, 14, 18]
#
# Step 1: Calculate the means of both groups.
# Mean of Medication A = (10 + 12 + 14 + 11 + 13) / 5 = 12
# Mean of Medication B = (15 + 17 + 16 + 14 + 18) / 5 = 16
#
# Step 2: Calculate the sum of squares between groups (SSB).
# SSB = (n1 * (mean of group 1 - overall mean)^2) + (n2 * (mean of group 2 - overall mean)^2)
# SSB = (5 * (12 - 14)^2) + (5 * (16 - 14)^2)
# SSB = 20 + 20
# SSB = 40
#
# Step 3: Calculate the sum of squares within groups (SSW).
# SSW = (n1 - 1) * variance of group 1 + (n2 - 1) * variance of group 2
# SSW = (4 * variance of Medication A) + (4 * variance of Medication B)
#
# To calculate the variance of each group:
# Variance of Medication A = [(10 - 12)^2 + (12 - 12)^2 + (14 - 12)^2 + (11 - 12)^2 + (13 - 12)^2] / (5 - 1)
# Variance of Medication A = 2 + 0 + 2 + 1 + 1
# Variance of Medication A = 6 / 4
# Variance of Medication A = 1.5
#
# Variance of Medication B = [(15 - 16)^2 + (17 - 16)^2 + (16 - 16)^2 + (14 - 16)^2 + (18 - 16)^2] / (5 - 1)
# Variance of Medication B = 1 + 1 + 0 + 4 + 4
# Variance of Medication B = 10 / 4
# Variance of Medication B = 2.5
#
# SSW = (4 * 1.5) + (4 * 2.5)
# SSW = 6 + 10
# SSW = 16
#
# Step 4: Calculate the mean squares between groups (MSB).
# MSB = SSB / degrees of freedom between groups
# MSB = SSB / (number of groups - 1)
# MSB = 40 / (2 - 1)
# MSB = 40 / 1
# MSB = 40
#
# Step 5: Calculate the mean squares within groups (MSW).
# MSW = SSW / degrees of freedom within groups
# MSW = SSW / (total number of observations - number of groups)
# MSW = SSW / (10 - 2)
# MSW = 16 / 8
# MSW = 2
#
# Step 6: Calculate the F-statistic.
# F-statistic = MSB / MSW
# F-statistic = 40 / 2
# F-statistic = 20
#
# Step 7: Determine the critical F-value and compare with the calculated F-statistic.
# With a significance level (alpha) of 0.05, and degrees of freedom between groups = 1, degrees of freedom within groups = 8, the critical F-value is approximately 4.747.
#
# Since the calculated F-statistic (20) is greater than the critical F-value (4.747), we can reject the null hypothesis. This indicates that there is a significant difference in the mean recovery times between Medication A and Medication B.
#
# In summary, based on the ANOVA results, there is sufficient evidence to suggest a significant difference in the mean recovery times between the two medications.

# %% [markdown]
# 10)
#
# Feedback ratings: [8, 9, 7, 6, 8, 10, 9, 8, 7, 8]
#
# Step 1: Sort the ratings in ascending order:
# [6, 7, 7, 8, 8, 8, 8, 9, 9, 10]
#
# Step 2: Calculate the index corresponding to the 75th percentile:
# Index = (75 / 100) * (N + 1)
# where N is the total number of data points
#
# Index = (75 / 100) * (10 + 1)
# Index = (0.75) * (11)
# Index = 8.25
#
# Step 3: Round the index up to the nearest whole number:
# Rounded Index = ceil(8.25)
# Rounded Index = 9
#
# Step 4: Find the value at the rounded index in the sorted data:
# 75th percentile = Value at index 9 = 9
#
# Therefore, the 75th percentile of the feedback ratings is 9.

# %% [markdown]
# 11)
#
# Weights of the sample products: [10.2, 9.8, 10.0, 10.5, 10.3, 10.1]
#
# Step 1: State the null and alternative hypotheses:
#
# Null hypothesis (H0): The mean weight is equal to 10 grams.
# Alternative hypothesis (H1): The mean weight differs significantly from 10 grams.
# Step 2: Set the significance level (alpha) for the test. Let's assume a significance level of 0.05 (5%).
#
# Step 3: Calculate the sample mean and sample standard deviation:
# Sample mean (x̄) = (10.2 + 9.8 + 10.0 + 10.5 + 10.3 + 10.1) / 6 = 10.17
# Sample standard deviation (s) = sqrt([(10.2 - 10.17)^2 + (9.8 - 10.17)^2 + (10.0 - 10.17)^2 + (10.5 - 10.17)^2 + (10.3 - 10.17)^2 + (10.1 - 10.17)^2] / (6 - 1)) ≈ 0.26
#
# Step 4: Calculate the t-value:
# t = (x̄ - μ) / (s / sqrt(n))
# where μ is the hypothesized mean, s is the sample standard deviation, and n is the sample size.
#
# t = (10.17 - 10) / (0.26 / sqrt(6)) ≈ 1.07
#
# Step 5: Determine the degrees of freedom:
# Degrees of freedom (df) = n - 1 = 6 - 1 = 5
#
# Step 6: Calculate the critical t-value based on the significance level and degrees of freedom. For a two-tailed test at a 5% significance level with 5 degrees of freedom, the critical t-value is approximately ±2.571.
#
# Step 7: Compare the calculated t-value with the critical t-value.
# Since the calculated t-value (1.07) does not exceed the critical t-value (±2.571), we fail to reject the null hypothesis.
#
# Step 8: Draw a conclusion:
# Based on the hypothesis test, there is not enough evidence to suggest that the mean weight differs significantly from 10 grams at the 5% significance level

# %% [markdown]
# 12)
#
# Design A: [100, 120, 110, 90, 95]
# Design B: [80, 85, 90, 95, 100]
#
# Step 1: Calculate the total number of clicks for each design.
#
# Total clicks for Design A = 100 + 120 + 110 + 90 + 95 = 515
#
# Total clicks for Design B = 80 + 85 + 90 + 95 + 100 = 450
#
# Step 2: Calculate the expected frequencies for each design.
#
# Expected frequency for Design A = (Total clicks for Design A) * (Total clicks for both designs) / (Total number of observations)
#
# Expected frequency for Design A = 515 * (515 + 450) / (515 + 450 + 515 + 450) ≈ 252.65
#
# Expected frequency for Design B = (Total clicks for Design B) * (Total clicks for both designs) / (Total number of observations)
#
# Expected frequency for Design B = 450 * (515 + 450) / (515 + 450 + 515 + 450) ≈ 252.65
#
# Step 3: Set up the null and alternative hypotheses:
#
# Null hypothesis (H0): There is no significant difference in click-through rates between Design A and Design B.
#
# Alternative hypothesis (H1): There is a significant difference in click-through rates between Design A and Design B.
#
# Step 4: Calculate the chi-square statistic.
# Chi-square statistic = Σ [(Observed frequency - Expected frequency)^2 / Expected frequency]
#
# Chi-square statistic = [(100 - 252.65)^2 / 252.65] + [(120 - 252.65)^2 / 252.65] + [(110 - 252.65)^2 / 252.65] + [(90 - 252.65)^2 / 252.65] + [(95 - 252.65)^2 / 252.65] + [(80 - 252.65)^2 / 252.65] + [(85 - 252.65)^2 / 252.65] + [(90 - 252.65)^2 / 252.65] + [(95 - 252.65)^2 / 252.65] + [(100 - 252.65)^2 / 252.65]
#
# Chi-square statistic ≈ 13.22
#
# Step 5: Determine the degrees of freedom.
#
# Degrees of freedom = (Number of rows - 1) * (Number of columns - 1)
#
# Degrees of freedom = (2 - 1) * (5 - 1) = 4
#
# Step 6: Determine the critical chi-square value based on the significance level and degrees of freedom. For a significance level of 0.05 and 4 degrees of freedom, the critical chi-square value is approximately 9.488.
#
# Step 7: Compare the calculated chi-square statistic with the critical chi-square value.
#
# Since the calculated chi-square statistic (13.22) is greater than the critical chi-square value (9.488), we reject the null hypothesis.
#
# Step 8: Draw a conclusion.
#
# Based on the chi-square test, there is sufficient evidence to suggest a a significant difference in the click-through rates between Design A and Design B.

# %% [markdown]
# 13)
#
# Data: [7, 9, 6, 8, 10, 7, 8, 9, 7, 8]
#
# Step 1: Calculate the sample mean and sample standard deviation.
# Sample mean (x̄) = (7 + 9 + 6 + 8 + 10 + 7 + 8 + 9 + 7 + 8) / 10 = 7.9
# Sample standard deviation (s) = sqrt([(7 - 7.9)^2 + (9 - 7.9)^2 + (6 - 7.9)^2 + (8 - 7.9)^2 + (10 - 7.9)^2 + (7 - 7.9)^2 + (8 - 7.9)^2 + (9 - 7.9)^2 + (7 - 7.9)^2 + (8 - 7.9)^2] / (10 - 1)) ≈ 1.019
#
# Step 2: Determine the sample size (n).
# Sample size (n) = 10
#
# Step 3: Calculate the standard error (SE).
# Standard error (SE) = s / sqrt(n)
# SE = 1.019 / sqrt(10) ≈ 0.322
#
# Step 4: Determine the critical value for a 95% confidence level. For a two-tailed test at a 95% confidence level, the critical value is approximately ±1.96.
#
# Step 5: Calculate the margin of error (ME).
# Margin of error (ME) = Critical value * SE
# ME = 1.96 * 0.322 ≈ 0.632
#
# Step 6: Calculate the lower and upper bounds of the confidence interval.
# Lower bound = Sample mean - Margin of error
# Lower bound = 7.9 - 0.632 ≈ 7.268
# Upper bound = Sample mean + Margin of error
# Upper bound = 7.9 + 0.632 ≈ 8.532
#
# Step 7: Formulate the confidence interval.
# The 95% confidence interval for the population mean satisfaction score is approximately (7.268, 8.532).
#
# Therefore, we can be 95% confident that the true population mean satisfaction score falls within the range of 7.268 to 8.532 based on the given sample data.

# %% [markdown]
# 14)
#
# Temperature (in degrees Celsius): [20, 22, 23, 19, 21]
#
# Performance (on a scale of 1 to 10): [8, 7, 9, 6, 8]
#
# Step 1: Calculate the means of both variables.
#
# Mean of Temperature = (20 + 22 + 23 + 19 + 21) / 5 = 21
#
# Mean of Performance = (8 + 7 + 9 + 6 + 8) / 5 = 7.6
#
# Step 2: Calculate the deviations from the mean for each variable.
#
# Deviation from the mean of Temperature = [20 - 21, 22 - 21, 23 - 21, 19 - 21, 21 - 21]
#
# Deviation from the mean of Temperature = [-1, 1, 2, -2, 0]
#
# Deviation from the mean of Performance = [8 - 7.6, 7 - 7.6, 9 - 7.6, 6 - 7.6, 8 - 7.6]
# Deviation from the mean of Performance = [0.4, -0.6, 1.4, -1.6, 0.4]
#
# Step 3: Calculate the product of the deviations for each pair of data points.
#
# Product of deviations = [-1 * 0.4, 1 * -0.6, 2 * 1.4, -2 * -1.6, 0 * 0.4]
#
# Product of deviations = [-0.4, -0.6, 2.8, 3.2, 0]
#
# Step 4: Calculate the sum of the product of deviations.
#
# Sum of product of deviations = -0.4 + -0.6 + 2.8 + 3.2 + 0 = 5
#
# Step 5: Calculate the squared deviations for Temperature.
#
# Squared deviations for Temperature = [(-1)^2, 1^2, 2^2, (-2)^2, 0^2]
#
# Squared deviations for Temperature = [1, 1, 4, 4, 0]
#
# Step 6: Calculate the sum of the squared deviations for Temperature.
# Sum of squared deviations for Temperature = 1 + 1 + 4 + 4 + 0 = 10
#
# Step 7: Calculate the slope (b) of the regression line.
#
# b = Sum of product of deviations / Sum of squared deviations for Temperature
#
# b = 5 / 10 = 0.5
#
# Step 8: Calculate the intercept (a) of the regression line.
#
# a = Mean of Performance - (b * Mean of Temperature)
#
# a = 7.6 - (0.5 * 21) = -0.1
#
# Step 9: Formulate the regression equation.
#
# Performance = Intercept + (Slope * Temperature)
#
# Performance = -0.1 + (0.5 * Temperature)
#
# Therefore, the regression equation to predict performance based on temperature is:
# Performance = -0.1 + 0.5 * Temperature

# %% [markdown]
# 15)
#
# Group A: [4, 3, 5, 2, 4]
# Group B: [3, 2, 4, 3, 3]
#
# Step 1: Combine the data from both groups and assign ranks to the observations, regardless of the group.
# Combined data: [4, 3, 5, 2, 4, 3, 2, 4, 3, 3]
# Ranks: [7, 4.5, 10, 1, 7, 4.5, 1, 7, 4.5, 4.5]
#
# Step 2: Calculate the sum of ranks for each group.
# Sum of ranks for Group A = 7 + 4.5 + 10 + 1 + 7 = 29.5
# Sum of ranks for Group B = 4.5 + 1 + 7 + 4.5 + 4.5 = 22
#
# Step 3: Calculate the U statistic for each group.
# U statistic for Group A = n1 * n2 + (n1 * (n1 + 1)) / 2 - Sum of ranks for Group A
# U statistic for Group A = 5 * 5 + (5 * (5 + 1)) / 2 - 29.5
# U statistic for Group A = 25 + 15 - 29.5 = 10.5
#
# U statistic for Group B = n1 * n2 + (n1 * (n1 + 1)) / 2 - Sum of ranks for Group B
# U statistic for Group B = 5 * 5 + (5 * (5 + 1)) / 2 - 22
# U statistic for Group B = 25 + 15 - 22 = 18
#
# Step 4: Determine the smaller U value (minU) between the two groups.
# minU = min(U statistic for Group A, U statistic for Group B) = min(10.5, 18) = 10.5
#
# Step 5: Determine the critical value for U at a desired significance level (alpha). For a two-tailed test at a 5% significance level with the given sample sizes (n1 = 5, n2 = 5), the critical value is approximately 10.
#
# Step 6: Compare the minU value with the critical value.
# Since the minU value (10.5) exceeds the critical value (10), we can reject the null hypothesis.
#
# Step 7: Draw a conclusion.
# Based on the Mann-Whitney U test, there is sufficient evidence to suggest a significant difference in the median preferences between Group A and Group B.

# %% [markdown]
# 16)
#
# Data: [25, 30, 35, 40, 45, 50, 55, 60, 65, 70]
#
# Step 1: Sort the data in ascending order:
# [25, 30, 35, 40, 45, 50, 55, 60, 65, 70]
#
# Step 2: Determine the lower quartile (Q1) and the upper quartile (Q3):
#
# Q1 is the median of the lower half of the data.
# Q3 is the median of the upper half of the data.
# Since we have an even number of data points, we can use the formula:
#
# Q1 = (Data[n/4] + Data[n/4 + 1]) / 2
# Q3 = (Data[3n/4] + Data[3n/4 + 1]) / 2
#
# Q1 = (Data[10/4] + Data[10/4 + 1]) / 2
# Q1 = (Data[2.5] + Data[3.5]) / 2
# Q1 = (35 + 40) / 2
# Q1 = 37.5
#
# Q3 = (Data[3 * 10/4] + Data[3 * 10/4 + 1]) / 2
# Q3 = (Data[7.5] + Data[8.5]) / 2
# Q3 = (60 + 65) / 2
# Q3 = 62.5
#
# Step 3: Calculate the interquartile range (IQR):
# IQR = Q3 - Q1
# IQR = 62.5 - 37.5
# IQR = 25
#
# Therefore, the interquartile range (IQR) of the ages is 25.

# %% [markdown]
# 17)
#
# Algorithm A: [0.85, 0.80, 0.82, 0.87, 0.83]
#
# Algorithm B: [0.78, 0.82, 0.84, 0.80, 0.79]
#
# Algorithm C: [0.90, 0.88, 0.89, 0.86, 0.87]
#
# Step 1: Combine the data from all algorithms.
#
# Combined data: [0.85, 0.80, 0.82, 0.87, 0.83, 0.78, 0.82, 0.84, 0.80, 0.79, 0.90, 0.88, 0.89, 0.86, 0.87]
#
# Step 2: Rank the data from the combined groups.
#
# Ranked data: [12, 4, 6, 15, 8, 2, 6, 10, 4, 1, 14, 11, 13, 9, 11]
#
# Step 3: Calculate the sum of ranks for each group.
#
# Sum of ranks for Algorithm A = 12 + 4 + 6 + 15 + 8 = 45
#
# Sum of ranks for Algorithm B = 2 + 6 + 10 + 4 + 1 = 23
#
# Sum of ranks for Algorithm C = 14 + 11 + 13 + 9 + 11 = 58
#
# Step 4: Calculate the mean ranks for each group.
#
# Mean rank for Algorithm A = 45 / 5 = 9
#
# Mean rank for Algorithm B = 23 / 5 = 4.6
#
# Mean rank for Algorithm C = 58 / 5 = 11.6
#
#
# Step 5: Calculate the Kruskal-Wallis test statistic (H):
#
# H = (12^2 / 5) + (4^2 / 5) + (6^2 / 5) + (15^2 / 5) + (8^2 / 5) + (2^2 / 5) + (6^2 / 5) + (10^2 / 5) + (4^2 / 5) + (1^2 / 5) + (14^2 / 5) + (11^2 / 5) + (13^2 / 5) + (9^2 / 5) + (11^2 / 5)
# H = 288 / 5 ≈ 57.6
#
# Step 6: Determine the critical value for the Kruskal-Wallis test at a desired significance level (alpha) and degrees of freedom (k - 1, where k is the number of groups). For a significance level of 0.05 and degrees of freedom of 2, the critical value is approximately 5.991.
#
# Step 7: Compare the test statistic (H) with the critical value.
# Since the test statistic (H = 57.6) exceeds the critical value (5.991), we reject the null hypothesis.
#
# Step 8: Draw a conclusion.
#
# Based on the Kruskal-Wallis test, there is sufficient evidence to suggest a significant difference in the median accuracy scores between Algorithm A, Algorithm B, and Algorithm C.

# %% [markdown]
# 18)
#
# Price (in dollars): [10, 15, 12, 8, 14]
#
# Sales: [100, 80, 90, 110, 95]
#
# Step 1: Calculate the means of both variables.
#
# Mean of Price = (10 + 15 + 12 + 8 + 14) / 5 = 11.8
#
# Mean of Sales = (100 + 80 + 90 + 110 + 95) / 5 = 95
#
# Step 2: Calculate the deviations from the mean for each variable.
#
# Deviation from the mean of Price = [10 - 11.8, 15 - 11.8, 12 - 11.8, 8 - 11.8, 14 - 11.8]
#
# Deviation from the mean of Price = [-1.8, 3.2, 0.2, -3.8, 2.2]
#
# Deviation from the mean of Sales = [100 - 95, 80 - 95, 90 - 95, 110 - 95, 95 - 95]
#
# Deviation from the mean of Sales = [5, -15, -5, 15, 0]
#
# Step 3: Calculate the product of the deviations for each pair of data points.
#
# Product of deviations = [-1.8 * 5, 3.2 * -15, 0.2 * -5, -3.8 * 15, 2.2 * 0]
#
# Product of deviations = [-9, -48, -1, -57, 0]
#
# Step 4: Calculate the sum of the product of deviations.
#
# Sum of product of deviations = -9 + -48 + -1 + -57 + 0 = -115
#
# Step 5: Calculate the squared deviations for Price.
#
# Squared deviations for Price = [(-1.8)^2, 3.2^2, 0.2^2, (-3.8)^2, 2.2^2]
#
# Squared deviations for Price = [3.24, 10.24, 0.04, 14.44, 4.84]
#
# Step 6: Calculate the sum of the squared deviations for Price.
#
# Sum of squared deviations for Price = 3.24 + 10.24 + 0.04 + 14.44 + 4.84 = 32.8
#
# Step 7: Calculate the slope (b) of the regression line.
#
# b = Sum of product of deviations / Sum of squared deviations for Price
#
# b = -115 / 32.8 ≈ -3.51
#
# Step 8: Calculate the intercept (a) of the regression line.
#
# a = Mean of Sales - (b * Mean of Price)
#
# a = 95 - (-3.51 * 11.8) ≈ 135.48
#
# Step 9: Formulate the regression equation.
#
# The regression equation is given by:
#
# Sales = Intercept + (Slope * Price)
#
# Sales = 135.48 + (-3.51 * Price)
#
# Therefore, the regression equation to predict sales based on price is:
#
# Sales = 135.48 - 3.51 * Price

# %% [markdown]
# 19)
#
# Data: [7, 8, 9, 6, 8, 7, 9, 7, 8, 7]
#
# Step 1: Calculate the sample mean.
# Sample mean (x̄) = (7 + 8 + 9 + 6 + 8 + 7 + 9 + 7 + 8 + 7) / 10 = 7.6
#
# Step 2: Calculate the deviations from the mean for each data point.
#
# Deviations from the mean = [7 - 7.6, 8 - 7.6, 9 - 7.6, 6 - 7.6, 8 - 7.6, 7 - 7.6, 9 - 7.6, 7 - 7.6, 8 - 7.6, 7 - 7.6]
#
# Deviations from the mean = [-0.6, 0.4, 1.4, -1.6, 0.4, -0.6, 1.4, -0.6, 0.4, -0.6]
#
# Step 3: Calculate the squared deviations.
#
# Squared deviations = [(-0.6)^2, 0.4^2, 1.4^2, (-1.6)^2, 0.4^2, (-0.6)^2, 1.4^2, (-0.6)^2, 0.4^2, (-0.6)^2]
#
# Squared deviations = [0.36, 0.16, 1.96, 2.56, 0.16, 0.36, 1.96, 0.36, 0.16, 0.36]
#
# Step 4: Calculate the sum of squared deviations.
#
# Sum of squared deviations = 0.36 + 0.16 + 1.96 + 2.56 + 0.16 + 0.36 + 1.96 + 0.36 + 0.16 + 0.36 = 8.32
#
# Step 5: Calculate the standard deviation.
#
# Standard deviation (s) = sqrt(Sum of squared deviations / (n - 1))
#
# Standard deviation (s) = sqrt(8.32 / (10 - 1)) ≈ 1.62
#
# Step 6: Calculate the standard error of the mean.
#
# Standard error of the mean (SE) = Standard deviation (s) / sqrt(n)
#
# Standard error of the mean (SE) = 1.62 / sqrt(10) ≈ 0.51

# %% [markdown]
# 20)
#
# Advertising Expenditure (in thousands): [10, 15, 12, 8, 14]
#
# Sales (in thousands): [25, 30, 28, 20, 26]
#
# Step 1: Set up the regression model.
#
# The regression model is given by:
#
# Sales = Intercept + (Coefficient1 * Advertising Expenditure)
#
# Step 2: Calculate the means of both variables.
#
# Mean of Advertising Expenditure = (10 + 15 + 12 + 8 + 14) / 5 = 11.8
#
# Mean of Sales = (25 + 30 + 28 + 20 + 26) / 5 = 25.8
#
# Step 3: Calculate the deviations from the mean for each variable.
#
# Deviation from the mean of Advertising Expenditure = [10 - 11.8, 15 - 11.8, 12 - 11.8, 8 - 11.8, 14 - 11.8]
#
# Deviation from the mean of Advertising Expenditure = [-1.8, 3.2, 0.2, -3.8, 2.2]
#
# Deviation from the mean of Sales = [25 - 25.8, 30 - 25.8, 28 - 25.8, 20 - 25.8, 26 - 25.8]
#
# Deviation from the mean of Sales = [-0.8, 4.2, 2.2, -5.8, 0.2]
#
# Step 4: Calculate the product of the deviations for each pair of data points.
# Product of deviations = [-1.8 * -0.8, 3.2 * 4.2, 0.2 * 2.2, -3.8 * -5.8, 2.2 * 0.2]
#
# Product of deviations = [1.44, 13.44, 0.44, 22.04, 0.44]
#
# Step 5: Calculate the sum of the product of deviations.
#
# Sum of product of deviations = 1.44 + 13.44 + 0.44 + 22.04 + 0.44 = 37.8
#
# Step 6: Calculate the squared deviations for Advertising Expenditure.
#
# Squared deviations for Advertising Expenditure = [(-1.8)^2, 3.2^2, 0.2^2, (-3.8)^2, 2.2^2]
#
# Squared deviations for Advertising Expenditure = [3.24, 10.24, 0.04, 14.44, 4.84]
#
# Step 7: Calculate the sum of the squared deviations for Advertising Expenditure.
# Sum of squared deviations for Advertising Expenditure = 3.24 + 10.24 + 0.04 + 14.44 + 4.84 = 32.8
#
# Step 8: Calculate the slope coefficient (Coefficient1).
#
# Coefficient1 = Sum of product of deviations / Sum of squared deviations for Advertising Expenditure
#
# Coefficient1 = 37.8 / 32.8 ≈ 1.15
#
# Step 9: Calculate the intercept coefficient (Intercept).
#
# Intercept = Mean of Sales - (Coefficient1 * Mean of Advertising Expenditure)
#
# Intercept = 25.8 - (1.15 * 11.8) ≈ 11.87
#
# Step 10: Formulate the regression equation.
#
# The regression equation is given by:
#
# Sales = Intercept + (Coefficient1 * Advertising Expenditure)
#
# Sales = 11.87 + (1.15 * Advertising Expenditure)
#
# Therefore, the regression equation to predict sales based on advertising expenditure is:
#
# Sales = 11.87 + 1.15 * Advertising Expenditure
